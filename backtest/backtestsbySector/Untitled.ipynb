# %%
# %run backtest_Telecom.py
# Out:
#                       GICS_SECTOR_NAME         TICKER  Q_Open_Price  PX_LAST  \
# DATE
# 2014-06-01  Telecommunication Services  CTL US Equity         32.81    36.20
# 2014-09-01  Telecommunication Services  CTL US Equity         36.22    40.89
# 2014-12-01  Telecommunication Services  CTL US Equity         40.72    39.58
# 2015-03-01  Telecommunication Services  CTL US Equity         39.83    34.55
# 2015-06-01  Telecommunication Services  CTL US Equity         34.51    29.38
# 2015-09-01  Telecommunication Services  CTL US Equity         29.49    25.12
# 2015-12-01  Telecommunication Services  CTL US Equity         25.12    25.16
# 2016-03-01  Telecommunication Services  CTL US Equity         24.85    31.96
# 2016-06-01  Telecommunication Services  CTL US Equity         31.82    29.01
# 2016-09-01  Telecommunication Services  CTL US Equity         29.00    27.43
# 2016-12-01  Telecommunication Services  CTL US Equity         27.44    23.78
# ...
